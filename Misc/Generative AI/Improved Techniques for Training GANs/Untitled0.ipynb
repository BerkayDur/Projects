# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook contains my implementation of the [Improved Techniques for Training GANs](https://arxiv.org/abs/1606.03498) paper. I start off by going through the theory of the paper and then implementing the main ideas as best I can within my resource constrained environment.

# %% [markdown]
# # Theory

# %% [markdown]
# **Contributions**
#
# The mains contributions of this paper are as follows:
#
# 1.
